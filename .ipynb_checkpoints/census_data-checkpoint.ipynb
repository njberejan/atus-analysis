# %% [markdown]
# # Sleep Trumps Equestrian Sports: An Analysis of American Activities via the U.S. Census

# %% [markdown]
# ### Import Everything

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import seaborn
# %matplotlib inline

# %% [markdown]
# ### Read in Activity File

# %%
census = pd.read_csv('data/atusact_2014.dat')

# %% [markdown]
# ### Cull Activity File to desired series

# %%
census = census[['TUCASEID', 'TUACTDUR', 'TRCODE', 'TEWHERE']]

# %% [markdown]
# ### Set Index to individual ID

# %%
census.set_index('TUCASEID')
# Out:
#                 TUACTDUR  TRCODE  TEWHERE
# TUCASEID
# 20140101140007       540   10101       -1
# 20140101140007        30   30101        1
# 20140101140007        60   10201       -1
# 20140101140007        10  181101       13
# 20140101140007        30  110101        4
# 20140101140007        20  181301       13
# 20140101140007        90  130116        9
# 20140101140007        25  181301       13
# 20140101140007        30  120303        1
# 20140101140007       725   10101       -1
# 20140101140011       150   10101       -1
# 20140101140011        30   10201       -1
# 20140101140011        30  180501       13
# 20140101140011       360   50101        2
# 20140101140011        15  110101        2
# 20140101140011       105   50101        2
# 20140101140011        20  180501       15
# 20140101140011        40  180501       16
# 20140101140011       120   10101       -1
# 20140101140011        20   20201        1
# 20140101140011        60  120303        1
# 20140101140011        30   10201       -1
# 20140101140011        40  120308        1
# 20140101140011        30  110101        1
# 20140101140011        60  120101        1
# 20140101140011        20   20203        1
# 20140101140011        40  120303        1
# 20140101140011       420   10101       -1
# 20140101140028        45   10201       -1
# 20140101140028       315   10101       -1
# ...                  ...     ...      ...
# 20141212142484        60  181101       12
# 20141212142484       120  110101        4
# 20141212142484        30  181302       12
# 20141212142484       270  130203       11
# 20141212142484        10  181101        9
# 20141212142484       120  110101        4
# 20141212142484        10  180405        9
# 20141212142484        30  180405       12
# 20141212142484        15   40507        3
# 20141212142484        15  180405       12
# 20141212142484        20   10201       -1
# 20141212142484       260   10101       -1
# 20141212142500       180   10101       -1
# 20141212142500        30  110101        1
# 20141212142500        45   10201       -1
# 20141212142500        15  181401       13
# 20141212142500       135  140101        5
# 20141212142500        15  181401       13
# 20141212142500        30  110101        1
# 20141212142500       150  120303        1
# 20141212142500        60   20101        1
# 20141212142500        60   20301        1
# 20141212142500        60   30103        1
# 20141212142500        60  120101        1
# 20141212142500        60  110101        1
# 20141212142500        60  120101        1
# 20141212142500        30   30101        1
# 20141212142500        30   20203        1
# 20141212142500        60  120303        1
# 20141212142500       585   10101       -1
#
# [223249 rows x 3 columns]

# %% [markdown]
# ### Read in CPS File (for demographic information)

# %%
cps_data = pd.read_csv('data/atuscps_2014.dat')

# %% [markdown]
# ### Cull CPS dataframe to desired series

# %%
cps_data = cps_data[['TUCASEID', 'GEREG', 'PRERNWA']]

# %% [markdown]
# ### Set index to individual ID

# %%
cps_data.set_index('TUCASEID')
# Out:
#                 GEREG  PRERNWA
# TUCASEID
# 20140101140005      3       -1
# 20140101140005      3       -1
# 20140101140007      4       -1
# 20140101140011      1       -1
# 20140101140011      1    82600
# 20140101140026      2       -1
# 20140101140028      3       -1
# 20140101140028      3    76923
# 20140101140028      3       -1
# 20140101140028      3       -1
# 20140101140028      3       -1
# 20140101140028      3       -1
# 20140101140041      3    35000
# 20140101140041      3    35000
# 20140101140041      3    35000
# 20140101140041      3    35000
# 20140101140041      3    36000
# 20140101140059      1       -1
# 20140101140063      3    65000
# 20140101140094      1    80769
# 20140101140096      2       -1
# 20140101140096      2       -1
# 20140101140096      2       -1
# 20140101140096      2       -1
# 20140101140096      2       -1
# 20140101140096      2       -1
# 20140101140096      2       -1
# 20140101140096      2       -1
# 20140101140096      2       -1
# 20140101140096      2       -1
# ...               ...      ...
# 20141212142462      2   125000
# 20141212142462      2   125000
# 20141212142462      2       -1
# 20141212142470      3       -1
# 20141212142470      3       -1
# 20141212142472      3    57692
# 20141212142476      4    44000
# 20141212142476      4    48000
# 20141212142476      4    48000
# 20141212142476      4    18000
# 20141212142479      3    36000
# 20141212142479      3       -1
# 20141212142479      3       -1
# 20141212142479      3       -1
# 20141212142479      3       -1
# 20141212142479      3       -1
# 20141212142480      4       -1
# 20141212142480      4       -1
# 20141212142480      4       -1
# 20141212142484      4       -1
# 20141212142484      4       -1
# 20141212142484      4       -1
# 20141212142484      4    18000
# 20141212142484      4       -1
# 20141212142496      3       -1
# 20141212142499      4       -1
# 20141212142500      3       -1
# 20141212142500      3   144230
# 20141212142500      3       -1
# 20141212142500      3       -1
#
# [68198 rows x 2 columns]

# %% [markdown]
# ### Merge the two dataframes to make one

# %%
census = census.merge(cps_data)

# %% [markdown]
# ### Check to see that merge is successful

# %%
census.head()
# Out:
#          TUCASEID  TUACTDUR  TRCODE  TEWHERE  GEREG  PRERNWA
# 0  20140101140007       540   10101       -1      4       -1
# 1  20140101140007        30   30101        1      4       -1
# 2  20140101140007        60   10201       -1      4       -1
# 3  20140101140007        10  181101       13      4       -1
# 4  20140101140007        30  110101        4      4       -1

# %% [markdown]
# ### Rename column titles for ease of reading

# %%
new_cols = ['Person_ID', 'Time_Spent', 'Activity', 'Where', 'Region', 'Income']
census.columns = new_cols

# %% [markdown]
# ### Verify change took effect

# %%
census.head()
# Out:
#         Person_ID  Time_Spent  Activity  Where  Region  Income
# 0  20140101140007         540     10101     -1       4      -1
# 1  20140101140007          30     30101      1       4      -1
# 2  20140101140007          60     10201     -1       4      -1
# 3  20140101140007          10    181101     13       4      -1
# 4  20140101140007          30    110101      4       4      -1

# %% [markdown]
# ### Replace "-1" value in income with "N/A"

# %%
census['Income'].replace('-1', 'N/A', inplace=True)

# %% [markdown]
# ### Check that change was made

# %%
census.head()
# Out:
#         Person_ID  Time_Spent  Activity  Where  Region Income
# 0  20140101140007         540     10101     -1       4    N/A
# 1  20140101140007          30     30101      1       4    N/A
# 2  20140101140007          60     10201     -1       4    N/A
# 3  20140101140007          10    181101     13       4    N/A
# 4  20140101140007          30    110101      4       4    N/A

# %% [markdown]
# ### Replace region values with region names

# %%
census['Region'].replace(1, 'Northeast', inplace=True)
census['Region'].replace(2, 'Midwest', inplace=True)
census['Region'].replace(3, 'South', inplace=True)
census['Region'].replace(4, 'West', inplace=True)

# %% [markdown]
# ### Replace where values with location names

# %%
census['Where'].replace('-1', 'N/A', inplace=True)
census['Where'].replace(1, 'Home', inplace=True)
census['Where'].replace(2, 'Workplace', inplace=True)
census['Where'].replace(3, 'Another\'s Home', inplace=True)
census['Where'].replace(4, 'Restaurant/Bar', inplace=True)
census['Where'].replace(5, 'Place of Worship', inplace=True)
census['Where'].replace(6, 'Grocery Store', inplace=True)
census['Where'].replace(7, 'Other Store/Mall', inplace=True)
census['Where'].replace(8, 'School', inplace=True)
census['Where'].replace(9, 'Outdoors', inplace=True)
census['Where'].replace(10, 'Library', inplace=True)
census['Where'].replace(11, 'Other Place', inplace=True)
census['Where'].replace(12, 'Automobile-Driver', inplace=True)
census['Where'].replace(13, 'Automobile-Passenger', inplace=True)
census['Where'].replace(14, 'Walking', inplace=True)
census['Where'].replace(15, 'Bus', inplace=True)
census['Where'].replace(16, 'Subway/Train', inplace=True)
census['Where'].replace(17, 'Bicycle', inplace=True)
census['Where'].replace(18, 'Boat/Ferry', inplace=True)
census['Where'].replace(19, 'Taxi/Limo', inplace=True)
census['Where'].replace(20, 'Airplane', inplace=True)
census['Where'].replace(21, 'Other Transport', inplace=True)
census['Where'].replace(30, 'Bank', inplace=True)
census['Where'].replace(31, 'Gym', inplace=True)
census['Where'].replace(32, 'Post Office', inplace=True)
census['Where'].replace(89, 'Unspecified', inplace=True)
census['Where'].replace(99, 'Unspecified Vehicle', inplace=True)

# %% [markdown]
# ### Check that values are replaced

# %%
census.head()
# Out:
#         Person_ID  Time_Spent  Activity                 Where Region Income
# 0  20140101140007         540     10101                   N/A   West    N/A
# 1  20140101140007          30     30101                  Home   West    N/A
# 2  20140101140007          60     10201                   N/A   West    N/A
# 3  20140101140007          10    181101  Automobile-Passenger   West    N/A
# 4  20140101140007          30    110101        Restaurant/Bar   West    N/A

# %% [markdown]
# ### Convert values in Activity column to string type object (so that 0 can be appended to front of 5 number values, for uniformity of data.)

# %%
census['Activity'] = census['Activity'].astype(str)

# %% [markdown]
# ### type function confirms values have been changed from "int" type to "str" type objects

# %%
type(census['Activity'][0])
# Out:
# str

# %% [markdown]
# ### Define function to add 0 to front of strings of less than 6 digits

# %%
def add_a_0(string):
    if len(string) < 6:
        return "0" + string
    else:
        return string

# %% [markdown]
# ### Run the function on the Activity series and update values accordingly

# %%
census['Activity'] = census['Activity'].apply(add_a_0)

# %% [markdown]
# ### Activity series now uniform in length

# %%
census.head()
# Out:
#         Person_ID  Time_Spent Activity                 Where Region Income
# 0  20140101140007         540   010101                   N/A   West    N/A
# 1  20140101140007          30   030101                  Home   West    N/A
# 2  20140101140007          60   010201                   N/A   West    N/A
# 3  20140101140007          10   181101  Automobile-Passenger   West    N/A
# 4  20140101140007          30   110101        Restaurant/Bar   West    N/A

# %% [markdown]
# ### Create a function to convert Time_Spent in minutes to hours

# %%
def convert_to_hours(time):
    return time/60

# %% [markdown]
# ### Apply function to series values

# %%
census['Time_Spent'] = census['Time_Spent'].apply(convert_to_hours)

# %% [markdown]
# ### Check that function has returned desired results

# %%
census.head()
# Out:
#         Person_ID  Time_Spent Activity                 Where Region Income
# 0  20140101140007    9.000000   010101                   N/A   West    N/A
# 1  20140101140007    0.500000   030101                  Home   West    N/A
# 2  20140101140007    1.000000   010201                   N/A   West    N/A
# 3  20140101140007    0.166667   181101  Automobile-Passenger   West    N/A
# 4  20140101140007    0.500000   110101        Restaurant/Bar   West    N/A

# %% [markdown]
# ### Create parallel dataframe grouped by activity and time, and average time spent per activity

# %%
activity_by_time = census[['Time_Spent', 'Activity']]

# %%
activity_by_time.head()
# Out:
#    Time_Spent Activity
# 0    9.000000   010101
# 1    0.500000   030101
# 2    1.000000   010201
# 3    0.166667   181101
# 4    0.500000   110101

# %%
activity_by_time = activity_by_time.groupby('Activity').mean()

# %% [markdown]
# ### Check that new dataframe contains desired data

# %%
activity_by_time.head()
# Out:
#           Time_Spent
# Activity
# 010101      5.468646
# 010102      1.294429
# 010201      0.483883
# 010299      1.096774
# 010301      0.838259

# %% [markdown]
# ### Sort values by average time spent from most to least

# %%
activity_by_time = activity_by_time.sort_values('Time_Spent', ascending=False)

# %% [markdown]
# ### Take the top ten activities by average length of time spent on that activity

# %%
top_ten = activity_by_time[:10]

# %%
top_ten.head()
# Out:
#           Time_Spent
# Activity
# 010101      5.468646
# 130210      4.900000
# 130226      4.843750
# 130118      4.728133
# 130299      4.217647

# %% [markdown]
# ### Reindex to be able to change Activity values

# %%
top_ten = top_ten.reset_index('Person_ID')

# %%
top_ten.head()
# Out:
#   Activity  Time_Spent
# 0   010101    5.468646
# 1   130210    4.900000
# 2   130226    4.843750
# 3   130118    4.728133
# 4   130299    4.217647

# %% [markdown]
# ### Replace activity numeric values with english language

# %%
top_ten['Activity'].replace('010101', 'Sleeping', inplace=True)
top_ten['Activity'].replace('130210', 'Watching Equestrian Sports', inplace=True)
top_ten['Activity'].replace('130226', 'Watching Vehicle Racing', inplace=True)
top_ten['Activity'].replace('130118', 'Hunting', inplace=True)
top_ten['Activity'].replace('130299', 'Attending Other Sporting Event', inplace=True)
top_ten['Activity'].replace('130112', 'Watching Fishing', inplace=True)
top_ten['Activity'].replace('040301', 'Providing Medical Care to Other People\'s Kids', inplace=True)
top_ten['Activity'].replace('130227', 'Watching Volleyball', inplace=True)
top_ten['Activity'].replace('050203', 'Sports and Exercise (With Coworkers)', inplace=True)
top_ten['Activity'].replace('050101', 'Working', inplace=True)

# %%
top_ten.head(10)
# Out:
#                                         Activity  Time_Spent
# 0                                       Sleeping    5.468646
# 1                     Watching Equestrian Sports    4.900000
# 2                        Watching Vehicle Racing    4.843750
# 3                                        Hunting    4.728133
# 4                 Attending Other Sporting Event    4.217647
# 5                               Watching Fishing    4.143447
# 6  Providing Medical Care to Other People's Kids    3.812500
# 7                            Watching Volleyball    3.672222
# 8           Sports and Exercise (With Coworkers)    3.564815
# 9                                        Working    3.255123

# %%
# top_ten.set_index('Activity')

# %% [markdown]
# ### Plot the top ten activities

# %%
top_ten['Time_Spent'].plot.bar(x=['Activity'], y=['Time_Spent'], figsize = (10, 7))

# %%
census.head()
# Out:
#         Person_ID  Time_Spent Activity                 Where Region Income
# 0  20140101140007    9.000000   010101                   N/A   West    N/A
# 1  20140101140007    0.500000   030101                  Home   West    N/A
# 2  20140101140007    1.000000   010201                   N/A   West    N/A
# 3  20140101140007    0.166667   181101  Automobile-Passenger   West    N/A
# 4  20140101140007    0.500000   110101        Restaurant/Bar   West    N/A

# %% [markdown]
# ### Create new copy of dataframe to view average amount of sleep by region

# %%
average_by_region = census[['Time_Spent', 'Activity', 'Region']]

# %%
average_by_region.set_index('Activity')
# Out:
#           Time_Spent     Region
# Activity
# 010101      9.000000       West
# 030101      0.500000       West
# 010201      1.000000       West
# 181101      0.166667       West
# 110101      0.500000       West
# 181301      0.333333       West
# 130116      1.500000       West
# 181301      0.416667       West
# 120303      0.500000       West
# 010101     12.083333       West
# 010101      2.500000  Northeast
# 010101      2.500000  Northeast
# 010201      0.500000  Northeast
# 010201      0.500000  Northeast
# 180501      0.500000  Northeast
# 180501      0.500000  Northeast
# 050101      6.000000  Northeast
# 050101      6.000000  Northeast
# 110101      0.250000  Northeast
# 110101      0.250000  Northeast
# 050101      1.750000  Northeast
# 050101      1.750000  Northeast
# 180501      0.333333  Northeast
# 180501      0.333333  Northeast
# 180501      0.666667  Northeast
# 180501      0.666667  Northeast
# 010101      2.000000  Northeast
# 010101      2.000000  Northeast
# 020201      0.333333  Northeast
# 020201      0.333333  Northeast
# ...              ...        ...
# 030103      1.000000      South
# 030103      1.000000      South
# 120101      1.000000      South
# 120101      1.000000      South
# 120101      1.000000      South
# 120101      1.000000      South
# 110101      1.000000      South
# 110101      1.000000      South
# 110101      1.000000      South
# 110101      1.000000      South
# 120101      1.000000      South
# 120101      1.000000      South
# 120101      1.000000      South
# 120101      1.000000      South
# 030101      0.500000      South
# 030101      0.500000      South
# 030101      0.500000      South
# 030101      0.500000      South
# 020203      0.500000      South
# 020203      0.500000      South
# 020203      0.500000      South
# 020203      0.500000      South
# 120303      1.000000      South
# 120303      1.000000      South
# 120303      1.000000      South
# 120303      1.000000      South
# 010101      9.750000      South
# 010101      9.750000      South
# 010101      9.750000      South
# 010101      9.750000      South
#
# [598459 rows x 2 columns]

# %%
activity_by_time.head()
# Out:
#           Time_Spent
# Activity
# 010101      5.468646
# 130210      4.900000
# 130226      4.843750
# 130118      4.728133
# 130299      4.217647

# %% [markdown]
# ### Merge region and activity dataframes with activity and average time spent dataframes

# %%
average_by_region.merge(activity_by_time)
# Out:
#          Time_Spent Activity     Region
# 0               0.5   030101       West
# 1               0.5   030101       West
# 2               0.5   030101       West
# 3               0.5   030101       West
# 4               0.5   030101       West
# 5               0.5   110101       West
# 6               0.5   110101       West
# 7               0.5   110101       West
# 8               0.5   110101       West
# 9               0.5   110101       West
# 10              0.5   120303       West
# 11              0.5   120303       West
# 12              0.5   120303       West
# 13              0.5   120303       West
# 14              0.5   120303       West
# 15              0.5   010201  Northeast
# 16              0.5   010201  Northeast
# 17              0.5   010201  Northeast
# 18              0.5   010201  Northeast
# 19              0.5   010201  Northeast
# 20              0.5   010201  Northeast
# 21              0.5   010201  Northeast
# 22              0.5   010201  Northeast
# 23              0.5   010201  Northeast
# 24              0.5   010201  Northeast
# 25              0.5   180501  Northeast
# 26              0.5   180501  Northeast
# 27              0.5   180501  Northeast
# 28              0.5   180501  Northeast
# 29              0.5   180501  Northeast
# ...             ...      ...        ...
# 1525537         1.2   120101       West
# 1525538         2.6   120303    Midwest
# 1525539         2.6   120303    Midwest
# 1525540         2.6   120303    Midwest
# 1525541         2.6   120303    Midwest
# 1525542         2.6   120303    Midwest
# 1525543         2.6   120303    Midwest
# 1525544         2.6   050101      South
# 1525545         2.6   140101  Northeast
# 1525546         2.6   140101  Northeast
# 1525547         2.6   010101      South
# 1525548         2.6   010101      South
# 1525549         2.6   010101      South
# 1525550         2.6   010101      South
# 1525551         2.6   050101    Midwest
# 1525552         2.6   050101    Midwest
# 1525553         2.6   050101    Midwest
# 1525554         2.6   050101    Midwest
# 1525555         2.6   050101       West
# 1525556         2.6   050101       West
# 1525557         2.6   050101       West
# 1525558         2.6   050101      South
# 1525559         2.6   050101      South
# 1525560         2.6   050101      South
# 1525561         2.6   050101      South
# 1525562         2.6   120404  Northeast
# 1525563         2.6   120404  Northeast
# 1525564         2.6   150102    Midwest
# 1525565         2.6   150102    Midwest
# 1525566         2.6   150102    Midwest
#
# [1525567 rows x 3 columns]

# %%
test_frame = average_by_region.groupby(['Activity', 'Region']).mean()

# %% [markdown]
# ### Create double indexed dataframe grouped by region and activity, and average time spent on each activity

# %%
sleep_by_region = test_frame['Time_Spent'][0:4]

# %% [markdown]
# ### Isolate just the sleep data

# %%
sleep_by_region.head()
# Out:
# Activity  Region
# 010101    Midwest      5.435374
#           Northeast    5.396346
#           South        5.535193
#           West         5.453893
# Name: Time_Spent, dtype: float64

# %% [markdown]
# ### Plot the results

# %%
sleep_by_region.plot.bar(figsize = (10, 7), yticks = range(7))

# %% [markdown]
# ### Obtain relevent information to correlate sleep time with income

# %%
income_vs_time = census[['Person_ID', 'Income', 'Time_Spent', 'Activity']]

# %%
income_vs_time.head()
# Out:
#         Person_ID Income  Time_Spent Activity
# 0  20140101140007    N/A    9.000000   010101
# 1  20140101140007    N/A    0.500000   030101
# 2  20140101140007    N/A    1.000000   010201
# 3  20140101140007    N/A    0.166667   181101
# 4  20140101140007    N/A    0.500000   110101

# %% [markdown]
# ### Convert string data in dataframe to numeric data

# %%
income_vs_time = income_vs_time.convert_objects(convert_numeric=True)
# Out:
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':

# %% [markdown]
# ### Drop instances where income is not determinable or respondant has no income

# %%
income_vs_time.dropna(inplace=True)

# %%
income_vs_time.head()
# Out:
#          Person_ID   Income  Time_Spent  Activity
# 11  20140101140011  82600.0        2.50     10101
# 13  20140101140011  82600.0        0.50     10201
# 15  20140101140011  82600.0        0.50    180501
# 17  20140101140011  82600.0        6.00     50101
# 19  20140101140011  82600.0        0.25    110101

# %% [markdown]
# ### Sort weekly income data from most to least

# %%
income_vs_time.sort_values('Income', ascending=False)
# Out:
#              Person_ID    Income  Time_Spent  Activity
# 117331  20140302140919  288461.0    0.333333    120101
# 516823  20141110141027  288461.0    0.500000     40103
# 516829  20141110141027  288461.0    2.500000    120303
# 516832  20141110141027  288461.0    0.250000    120312
# 516835  20141110141027  288461.0    9.000000     10101
# 171730  20140403141094  288461.0    3.000000     10101
# 171736  20140403141094  288461.0    1.000000    120312
# 171742  20140403141094  288461.0    1.000000    110101
# 171748  20140403141094  288461.0    0.333333     20902
# 171754  20140403141094  288461.0    0.083333     20202
# 171760  20140403141094  288461.0    0.116667     20203
# 171766  20140403141094  288461.0    0.116667     20102
# 171772  20140403141094  288461.0    0.350000    120312
# 171778  20140403141094  288461.0    0.166667     30101
# 171784  20140403141094  288461.0    0.166667     30101
# 171790  20140403141094  288461.0    0.250000     20201
# 171796  20140403141094  288461.0    0.416667     30106
# 74299   20140201141768  288461.0    0.166667     30112
# 74294   20140201141768  288461.0    0.083333    180301
# 74289   20140201141768  288461.0    0.333333     10201
# ...                ...       ...         ...       ...
# 571503  20141211141347       0.0    5.333333     50101
# 571453  20141211141347       0.0    3.500000     10101
# 571508  20141211141347       0.0    0.250000    180501
# 571513  20141211141347       0.0    1.000000    120312
# 571518  20141211141347       0.0    1.250000     20201
# 571523  20141211141347       0.0    0.250000    180301
# 571528  20141211141347       0.0    0.083333     30112
# 571533  20141211141347       0.0    0.166667    180301
# 571538  20141211141347       0.0    0.083333     30112
# 571458  20141211141347       0.0    0.500000     10201
# 204462  20140503141847       0.0    3.000000     50101
# 234370  20140504141836       0.0    2.000000     20101
# 204512  20140503141847       0.0    2.000000     10101
# 234374  20140504141836       0.0    1.750000    130104
# 204542  20140503141847       0.0    1.750000     50101
# 204537  20140503141847       0.0    0.250000    120301
# 204532  20140503141847       0.0    1.750000     50101
# 204527  20140503141847       0.0    0.250000    110101
# 204522  20140503141847       0.0    2.666667     50101
# 204517  20140503141847       0.0    0.333333    180501
# 204507  20140503141847       0.0    1.000000     20201
# 204467  20140503141847       0.0    0.250000    180501
# 204502  20140503141847       0.0    2.000000     20101
# 204497  20140503141847       0.0    5.833333     10101
# 204492  20140503141847       0.0    0.166667    110101
# 204487  20140503141847       0.0    0.166667    180209
# 204482  20140503141847       0.0    0.166667     20902
# 204477  20140503141847       0.0    0.166667    180209
# 204472  20140503141847       0.0    3.250000     10101
# 447704  20140909141923       0.0    0.416667    110101
#
# [238012 rows x 4 columns]

# %% [markdown]
# ### Isolate just the data coresponding to sleep activity

# %%
sleep_only = income_vs_time.loc[income_vs_time['Activity'] == 10101]

# %%
sleep_only.head()
# Out:
#           Person_ID   Income  Time_Spent  Activity
# 11   20140101140011  82600.0        2.50     10101
# 27   20140101140011  82600.0        2.00     10101
# 45   20140101140011  82600.0        7.00     10101
# 53   20140101140028  76923.0        5.25     10101
# 101  20140101140028  76923.0        4.00     10101

# %% [markdown]
# ### Graph histogram of responses

# %%
sleep_only[['Income', 'Time_Spent']].hist(figsize=(10, 7))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11b426550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b3aa828>]], dtype=object)

# %% [markdown]
# ### Run Pandas correlate function to determine correlation between time spent sleeping and income.

# %%
sleep_only.corr()
# Out:
#             Person_ID    Income  Time_Spent  Activity
# Person_ID    1.000000 -0.006739    0.005768       NaN
# Income      -0.006739  1.000000   -0.041922       NaN
# Time_Spent   0.005768 -0.041922    1.000000       NaN
# Activity          NaN       NaN         NaN       NaN

# %% [markdown]
# # Conclusions:

# %% [markdown]
# 1. People are very much into watching sports on TV, to the detriment of things such as work or taking care of their own children. The sports which are being watched are not what one might expect (notably volleyball, equestrian sports) Personal hygeine does not even crack the top ten. I suspect this is due to some outliers throwing off the data, where someone may have reported starting to watch, say, beach volleyball on ESPN12, but did not report another activity after, which assumes that that person continued watching until the 4am cutoff. The data recorded would reflect an unlikely number of hours of volleyball watched in one day.
# 2. People in the South sleep, on average, slightly more than Americans in other regions of the country. However, the difference on average from region to region is insignificant.
# 3. There is a slight negative correlation between number of hours of sleep one gets on average and weekly income. This suggests that the more affluent do not sleep as much as others, although it must be noted the correlation is not particularly strong.
